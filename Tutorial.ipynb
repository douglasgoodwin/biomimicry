# %%
from lsys import Lsys

# %%
l=Lsys("X",["X->X[F-X][F+X]","F->FF"])
l.set_seed(0)
l.render(iteration=7,
         length="randint(1,9)", 
         angle="randint(-50,50)*0.2+20", 
         initial_pos=[0,-300]
        )
